# %%
from random import choice

gestures = ['rock', 'paper', 'scissors']
n_rounds = ()
WINS = GAMES//2 + 1

def machine_choice(options=gestures):
     return choice(options)

def human_choice(options=gestures):
        while True:
            p2 = input('rock, paper, scissors: ')
            if p2 in options:
                break
        return p2

def combat(op_pc, op_player):
        if op_pc == op_player:
            return 0
        if op_pc == 'rock':
                return 2 if op_player == 'paper' else 1
        if op_pc == 'paper':
            return 2 if op_player == 'scissors' else 1
        if op_pc == 'scissors':
            return 2 if op_player == 'rock' else 1
    
    
def print_state(p1, p2, points_p1, points_p2):
        print('IA chose {}\\nHuman chose {}'.format(p1, p2))
        print('IA has {} points\\nHuman has {} poins'.format(points_p1, points_p2))
        print('##################')
    
computer_wins, player_wins  = 0, 0
    
while player_wins < WINS and computer_wins < WINS:
        p1 = machine_choice()
        p2 = human_choice()
        c = combat(p1, p2)
    
        if c == 1:
            computer_wins += 1
        elif c == 2: 
            player_wins += 1
        
print('State', p1, p2, computer_wins, player_wins)
    
if player_wins > computer_wins:
    print('Humanity wins')
else:
    print('IA wins')
   
#Now the improvement begins
    
#from random import choice
#def get_integer_odd():
#        res = 0\
       # while res%2 != 1: 
           # try:
            #    res = int(input('Insert even number: '))
            #except:
             #   print('Wrong input')
        #return res    
    
OPTIONS = ['rock', 'paper', 'scissors', 'lizard', 'spock']
games = get_integer_odd():
WINS = games//2 + 1\n",

  def machine_choice(options=OPTIONS):
    return choice(options)
    
      def human_choice(options=OPTIONS):
        while True:
            p2 = input('rock, paper, scissors, lizard, spock')
            if p2 in options:
                break
        return p2
   
  def combat(op_pc, op_player): 
        if op_pc == op_player: 
            return 0
        if op_pc == 'rock': 
            return 2 if (op_player == 'paper' or op_player == 'spock') else 1
        if op_pc == 'paper': 
            return 2 if (op_player == 'scissors' or op_player == 'lizard') else 1  
        if op_pc == 'scissors': 
            return 2 if (op_player == 'rock' or op_player == 'spock') else 1  
        if op_pc == 'lizard': 
            return 2 if (op_player == 'rock' or op_player == 'scissors') else 1 
        if op_pc == 'spock': 
            return 2 if (op_player == 'paper' or op_player == 'lizard') else 1 
    
    
    
def print_state(p1, p2, points_p1, points_p2): 
        print('IA chose {}\\nHuman chose {}'.format(p1, p2)),
        print('IA has {} points\\nHuman has {} poins'.format(points_p1, points_p2))
        print('##################')
    
computer_wins, player_wins  = 0, 0
    
    
    while player_wins < WINS and computer_wins < WINS:
        p1 = machine_choice()
        p2 = human_choice()
        c = combat(p1, p2)
        if c == 1:
            computer_wins += 1
        elif c == 2:
            player_wins += 1

        print('State', p1, p2, computer_wins, player_wins)
    
        if player_wins > computer_wins: 
        print('Humanity wins')
        else: 
        print('IA wins')
# Out:
#   File "<ipython-input-34-b7c77c26f6cb>", line 65
#     games = get_integer_odd():
#                              ^
# SyntaxError: invalid syntax

# %%
from random import choice

gestures = ['rock', 'paper', 'scissors']
n_rounds = ()
#Remember that the number of rounds must be odd: 1, 3, 5, ...
games = 0
rounds_to_win  = games//2 + 1
cpu_score = 0
player_score = 0
wins = 0
player_wins = 0
cpu_wins = 0

#6. Define a function that randomly returns one of the 3 gesture options

def machine_choice(options=gestures):
     return choice(options)

#7. Define a function that asks the player which is the gesture he or she wants to show: 'rock', 'paper' or 'scissors'
def human_choice(options=gestures):
        while True:
            p2 = input('rock, paper, scissors: ')
            if p2 in options:
                break
        return p2
   

    #8. Define a function that checks who won a round

def combat(op_pc, op_player):
        if cpu_score == player_score:
            return 0
        if cpu_score == 'rock':
                return 2 if player_score == 'paper' else 1
        if cpu_score == 'paper':
            return 2 if player_score == 'scissors' else 1
        if cpu_score == 'scissors':
            return 2 if player_score == 'rock' else 1
        
#9. Define a function that prints the choice of the computer, the choice of the player and a message 
#that announces who won the current round. You should also use this function to update the variables 
#that count the number of rounds that the computer and the player have won. The score of the winner increases by one point. 
#If there is a tie, the score does not increase.

def print_state(p1, p2, points_p1, points_p2): 
        print('IA chose {}\\nHuman chose {}'.format(p1, p2)),
        print('IA has {} points\\nHuman has {} poins'.format(points_p1, points_p2))
        print('##################')
    
computer_wins, player_wins  = 0, 0
cpu_score = 0
player_score = 0  
    
    while player_wins < WINS and computer_wins < WINS:
        p1 = machine_choice()
        p2 = human_choice()
        c = combat(p1, p2)
        if c == 1:
            computer_wins += 1
        elif c == 2:
            player_wins += 1

        print('State', p1, p2, computer_wins, player_wins)
    
        if player_wins > computer_wins: 
        print('Humanity wins')
        else: 
        print('IA wins')

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Insid

#e the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.


    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
#   File "<ipython-input-1-ef5a70f3d183>", line 54
#     while player_wins < WINS and computer_wins < WINS:
#     ^
# IndentationError: unexpected indent

# %%
import random


gestures = ['rock', 'paper', 'scissors']

n_rounds = 0
wins = 0
player_wins = 0
player_choice = ''
cpu_choice = ''
cpu_wins = 0
cpu_score = 0
player_score = 0



n_rounds = int(input('How many rounds do you want to play? Please insert an odd number.'))
if ((n_rounds%2) == 0):
    print('The number of rounds should be odd. That is why you won another round!')
    n_rounds = n_rounds +1

wins = (n_rounds // 2) + 1

while (cpu_score < wins and player_score < wins):
    print('Please choose your gesture.')
    while True:
        player_choice = input('rock, paper, scissors: ')
        if player_choice in gestures:
            break

    cpu_choice = (random.choice(gestures))
    print('Computer\'s choice: ', cpu_choice)

    if cpu_choice == player_choice:
        print('It\'s a tie!')
    elif (cpu_choice == 'rock'):
        if (player_choice == 'scissors'):
            print('Computer won this round')
            cpu_score = cpu_score + 1
        else:
            print('You won this round')
            player_score = player_score + 1
    elif (cpu_choice == 'paper'):
        if (player_choice == 'rock'):
            print('Computer won this round')
            cpu_score = cpu_score + 1
        else:
            print('You won this round')
            player_score = player_score + 1
    elif (cpu_choice == 'scissors'):
        if (player_choice == 'paper'):
            print('Computer won this round')
            cpu_score = cpu_score + 1
        else:
            print('You won this round')
            player_score = player_score + 1
    print('Scores: Computer ', cpu_score, ' X ', player_score, ' You')
    print(' ')         
    
if (cpu_score > player_score):
    print('Computer won this game   :(   ')
else:
    print('You won this game   :D    ')
# Out:
# How many rounds do you want to play? Please insert an odd number.3
# Please choose your gesture.
# rock, paper, scissors: paper
# Computer's choice:  scissors
# Computer won this round
# Scores: Computer  1  X  0  You
#
# Please choose your gesture.
# rock, paper, scissors: paer
# rock, paper, scissors: paper
# Computer's choice:  rock
# You won this round
# Scores: Computer  1  X  1  You
#
# Please choose your gesture.
# rock, paper, scissors: paper
# Computer's choice:  paper
# It's a tie!
# Scores: Computer  1  X  1  You
#
# Please choose your gesture.
# rock, paper, scissors: paper
# Computer's choice:  scissors
# Computer won this round
# Scores: Computer  2  X  1  You
#
# Computer won this game   :(

# %%
# Import the choice function of the random module


# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking


# Assign a list of 5 possible options.


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.


# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
 

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

    
    
# Print by console the winner of the game based on who has more accumulated wins
