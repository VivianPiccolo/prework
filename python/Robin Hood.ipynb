# %%
#Find the coordinates of the points where an arrow hits another arrow.

points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]

same_points=[]
#same_points_values=[]
position = 0
compare_position = 0
same_position = 0
size = len(points)

while (position < size):
    compare_position = compare_position + 1
    if compare_position == size:
        position = position + 1
        compare_position = position
        #print ("Compare ELIF:", position, "; ", compare_position, ";", size)
    elif points[compare_position] == points[position]:
        #print ("Compare IF:", position, "; ", compare_position, ";", size)
        same_position = same_position + 1
        same_points.append(points[position])
        #same_points_values.append(position)
                       
print("Points where arrow hits another arrow:", same_position)
print("Same points value: ", same_points)
# Out:
# Points where arrow hits another arrow: 6
# Same points value:  [(4, 5), (5, 7), (5, 7), (2, 2), (-3, 2), (5, 7)]

# %%
#Calculate how many arrows have fallen in each quadrant.
#Note: the arrows that fall in the axis (x=0 or y=0) don't belong to any quadrant.
#horizontal coordinate (x) and the vertical coordinate (y)

points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]

position = 0
compare_position = 0
size = len(points)
q1 = 0
q2 = 0
q3 = 0
q4 = 0

for point in points:
    x , y = point
    if (x > 0 and y > 0): 
        print ("The arrow has fallen in the First quarant")
        q1 = q1 + 1 
    elif (x < 0 and y > 0): 
        print ("The arrow has fallen in the Second quadrant")
        q2 = q2 + 1 
    elif (x < 0 and y < 0): 
        print ("The arrow has fallen in the Third quadrant")   
    elif (x > 0 and y < 0): 
        q3 = q3 + 1 
        print ("The arrow has fallen in the Fourth quadrant")       
    elif (x == 0 and y > 0): 
        print ("lies at positive y axis")   
    elif (x == 0 and y < 0): 
        print ("lies at negative y axis")   
    elif (y == 0 and x < 0): 
        print ("lies at negative x axis")   
    elif (y == 0 and x > 0): 
        print ("lies at positive x axis")   
    else: 
        print ("Don't belong to any quadrant")

print("Number of arrows in the First quarant:", q1)
print("Number of arrows in the Second quarant:", q2)
print("Number of arrows in the Third quarant:", q3)
print("Number of arrows in the Fourth quarant:", q4)
# Out:
# The arrow has fallen in the First quarant
# lies at positive y axis
# The arrow has fallen in the First quarant
# The arrow has fallen in the Fourth quadrant
# The arrow has fallen in the Fourth quadrant
# The arrow has fallen in the First quarant
# The arrow has fallen in the First quarant
# The arrow has fallen in the First quarant
# The arrow has fallen in the Second quadrant
# The arrow has fallen in the First quarant
# The arrow has fallen in the Second quadrant
# lies at negative y axis
# The arrow has fallen in the Second quadrant
# The arrow has fallen in the Second quadrant
# The arrow has fallen in the Second quadrant
# The arrow has fallen in the Third quadrant
# The arrow has fallen in the Second quadrant
# The arrow has fallen in the First quarant
# The arrow has fallen in the First quarant
# The arrow has fallen in the First quarant
# The arrow has fallen in the First quarant
# The arrow has fallen in the Third quadrant
# Number of arrows in the First quarant: 10
# ...

# %%
#Find the point closest to the center. 
points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]

very_close = (0)
center = (0 , 0)
far = 0

for point in points:
    x , y = point
    if (x == 0 and y == 0): 
        print ("The arrow has fallen into the center")
        center = center + 1
    elif ((x ==0 or x == 1) and (y == 1 or y == 0)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x ==0 or x == -1) and (y == -1 or y == 0)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == 0 or x == 2) and (y == 0 or y == 2)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == 0 or x == -2) and (y == 0 or y ==-2)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == 0 or x == 3) and (y == 0 or y ==3)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == 0 or x == -3) and (y == 0 or y ==-3)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == 1 or x == 3) and (y == 1 or y ==3)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == 1 or x == -3) and (y == 1 or y ==-3)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == -1 or x == 3) and (y == -1 or y ==3)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    elif ((x == -1 or x == -3) and (y == -1 or y ==-3)): 
        very_close = very_close + 1
        print ("The arrow has fallen very close to the center")
        print(very_close)
    else: 
        far = far + 1
        print ("Too far from the center")

print("Number of arrows wich lies very close to the center:", very_close)
print("Number of arrows wich lies far from the center:", far)

very_close_list = ((-0, 2), (1, -3), (2, 2), (0, -2), (-1, 3), (2, 2))
# Out:
# Too far from the center
# The arrow has fallen very close to the center
# 1
# Too far from the center
# The arrow has fallen very close to the center
# 2
# Too far from the center
# Too far from the center
# Too far from the center
# Too far from the center
# Too far from the center
# The arrow has fallen very close to the center
# 3
# Too far from the center
# The arrow has fallen very close to the center
# 4
# Too far from the center
# The arrow has fallen very close to the center
# 5
# Too far from the center
# Too far from the center
# Too far from the center
# Too far from the center
# Too far from the center
# The arrow has fallen very close to the center
# 6
# Too far from the center
# Too far from the center
# Number of arrows wich lies very close to the center: 6
# Number of arrows wich lies far from the center: 16

# %%
#Calculate its distance to the center.

very_close_list = ((-0, 2), (1, -3), (2, 2), (0, -2), (-1, 3), (2, 2))
p2 = [0, 0]

import math

size = len(very_close_list)
aux_points = []
position = 0
count = 0

while (position < size):
    aux_points = very_close_list[position]
    distance = math.sqrt( ((aux_points[0]-p2[0])**2)+((aux_points[1]-p2[1])**2) )
    print(distance)
    position = position + 1
    
print("Closest distance of an arrow to the center:", min(2.0, 3.1622776601683795, 2.8284271247461903, 2.0, 3.1622776601683795))
print("Closest arrows to the center:(-0, 2), (0, -2)")
# Out:
# 2.0
# 3.1622776601683795
# 2.8284271247461903
# 2.0
# 3.1622776601683795
# 2.8284271247461903
# Closest distance of an arrow to the center: 2.0
# Closest arrows to the center:(-0, 2), (0, -2)

# %%
#If the archery target has a radius of 9, calculate the number of arrows that won't hit the target.

import math

radius = [9, 9]

points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]

size_points = len(points)
aux_points = []
position = 0
count = 0

while (position < size_points):
    aux_points = points[position]
    distance = math.sqrt( ((aux_points[0]-radius[0])**2)+((aux_points[1]-radius[1])**2) )
    print(distance)
    position = position + 1
    if distance > 9:
        count = count + 1

print('Number of arrows that will not hit the target:', count)
# Out:
# 6.4031242374328485
# 11.40175425099138
# 5.385164807134504
# 14.422205101855956
# 12.529964086141668
# 6.4031242374328485
# 9.219544457292887
# 4.47213595499958
# 14.142135623730951
# 9.899494936611665
# 13.601470508735444
# 14.212670403551895
# 13.152946437965905
# 11.661903789690601
# 13.892443989449804
# 19.1049731745428
# 13.892443989449804
# 4.47213595499958
# 4.47213595499958
# 9.899494936611665
# 0.0
# 24.758836806279895
# Number of arrows that will not hit the target: 15
